# %%
import pandas as pd
import pickle
import matplotlib.pyplot as plt

import utilsEvaluation

# %%
# %matplotlib inline

# %% [markdown]
# #### Load the data

# %%
rxnCls = pickle.load(file('data/rxnClasses.pickle'))

# %%
dataSetA = pd.read_csv('data/dataSetA.csv')

# %%
dataSetA['reactantSet'] = [eval(x) for x in dataSetA['reactantSet']]

# %%
dataSetB = pd.read_csv('data/dataSetB.csv')

# %%
dataSetB['reactantSet_NameRxn'] = [eval(x) for x in dataSetB['reactantSet_NameRxn']]
dataSetB['reactantSet_IndigoTK'] = [eval(x) for x in dataSetB['reactantSet_IndigoTK']]
dataSetB['reactantSet_IndigoAutoMapperKNIME'] = [eval(x) for x in dataSetB['reactantSet_IndigoAutoMapperKNIME']]

# %% [markdown]
# #### Evalution on data set A

# %%
numDifferences, timings, numSol = utilsEvaluation.calcNumDifferences(dataSetA, 1, 3, 4, useBaseline=True)

# %%
fig = utilsEvaluation.plotNumberDifferences(numDifferences)
fig.savefig("dataSetA_overall_Baseline.png", dpi=300, format='png', bbox_inches='tight')
# Out:
# [0.17862371888726208, 0.5314787701317716, 0.1493411420204978, 0.11273792093704246, 0.024890190336749635]

# %%
fig = utilsEvaluation.plotNumberDifferencesRxnCls(numDifferences,rxnCls)
fig.savefig("dataSetA_rxnclasses_Baseline.png", dpi=300, format='png', bbox_inches='tight')

# %% [markdown]
# #### Evalution on data set B

# %%
numDifferences, timings, numSol = utilsEvaluation.calcNumDifferences(dataSetB, 1, 3, 4, useBaseline=True)
# Out:
# done 10000
# done 20000
# done 30000
# done 40000
# done 50000

# %%
fig = utilsEvaluation.plotNumberDifferences(numDifferences)
fig.savefig("dataSetB_overall_Baseline.png", dpi=300, format='png', bbox_inches='tight')
# Out:
# [0.35688, 0.4321, 0.1587, 0.0422, 0.00942]

# %%
fig = utilsEvaluation.plotNumberDifferencesRxnCls(numDifferences,rxnCls)
fig.savefig("dataSetB_rxnclasses_Baseline.png", dpi=300, format='png', bbox_inches='tight')
